# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import cv2
drive.mount('/content/gdrive')
#영상 불러오기
img = cv2.imread('/content/gdrive/My Drive/Image_Processing/lena.jpg')

#영상 화면에 표시하기
cv2_imshow(img)
#영상을 디렉토리에 새로운 이름으로 저장하기
cv2.imwrite('/content/gdrive/My Drive/Image_Processing/leng2.jpg',img)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F7F0E439DD0>
# True
