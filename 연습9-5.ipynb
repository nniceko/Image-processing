# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

# %%
img1 = cv2.imread('/content/gdrive/My Drive/Image_Processing/Picture4.png')
img2 = cv2.imread('/content/gdrive/My Drive/Image_Processing/rice.bmp')
kernel = np.ones((5,5),np.uint8)
opening1 = cv2.morphologyEx(img1, cv2.MORPH_OPEN, kernel)
opening2 = cv2.morphologyEx(img2, cv2.MORPH_OPEN, kernel)
print("Original image")
cv2_imshow(img1)
print("Binary opening")
cv2_imshow(opening1)
print("Original image")
cv2_imshow(img2)
print("Gray opening")
cv2_imshow(opening2)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=329x329 at 0x7F756EBE6A10>
# Binary opening
# <PIL.Image.Image image mode=RGB size=329x329 at 0x7F756EBE6AD0>
# Original image
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F756EBE68D0>
# Gray opening
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F756EBE68D0>
