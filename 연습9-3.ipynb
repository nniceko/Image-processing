# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

# %%
#영상 불러오기
img = cv2.imread('/content/gdrive/My Drive/Image_Processing/char.bmp')
kernel = np.ones((3,3),np.uint8)
erosion1 = cv2.erode(img,kernel,iterations = 1)
print("Original image")
cv2_imshow(img)
print("Erosion 1 image")
cv2_imshow(erosion1)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FED076FA710>
# Erosion 1 image
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FED07695550>
