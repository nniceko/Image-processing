# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

# %%
img = cv2.imread('/content/gdrive/My Drive/Image_Processing/rice.bmp')
kernel = np.ones((3,3),np.uint8)
erode1 = cv2.erode(img,kernel,iterations = 1)
erode3 = cv2.erode(img,kernel,iterations = 3)
print("Original image")
cv2_imshow(img)
print("Erosion 1 image")
cv2_imshow(erode1)
print("Erosion 3 image")
cv2_imshow(erode3)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F7FAA304F10>
# Erosion 1 image
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F7FAA2FAED0>
# Erosion 3 image
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F7FAA2FAA90>
