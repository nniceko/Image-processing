# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

# %%
img = cv2.imread('/content/gdrive/My Drive/Image_Processing/aero2.bmp')
kernel = np.ones((5,5),np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
print("Original image")
cv2_imshow(img)
print("Closing gray image")
cv2_imshow(closing)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAAF5702E90>
# Closing gray image
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAB04ADE890>
