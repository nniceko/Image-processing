# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2
import matplotlib.pyplot as plt

# %%
# 영상을 불러오기
img = cv2.imread('/content/gdrive/MyDrive/Colab Notebooks/book_image/butterfly.bmp', 0)

# cv2.dft 함수를 이용하여 영상의 이산푸리에 변환 수행
dft = cv2.dft(np.float32(img), flags = cv2.DFT_COMPLEX_OUTPUT)
# DC성분이 중심으로 오도록 주파수 중심을 이동
dft_shift = np.fft.fftshift(dft)
# DFT 결과의 크기값에 로그를 취하여 육안으로 확인이 용이하도록 함
mag_dft = 20*np.log(cv2.magnitude(dft[:,:,0], dft[:,:,1]))
mag_dft_shift = 20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
# 결과값을 출력
cv2_imshow(img)
cv2_imshow(mag_dft)
cv2_imshow(mag_dft_shift)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F9DD78DC610>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F9DD7916C50>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F9DD78DC610>
